# %%
using HTTP
using JSON

url = "http://api.weatherunlocked.com/api/forecast/10.16202,-68.00765?app_id=f8341b8f&app_key=380d876792d6ac1b32c5258c07c010a4"

res = HTTP.get(url)
json = JSON.parse(String(res.body))
println(json)
# Out:
# Dict{String, Any}("Days" => Any[Dict{String, Any}("rain_total_in" => 0.0, "temp_min_c" => 21.2, "moonrise_time" => "08:57", "slp_min_mb" => 1013.5, "prob_precip_pct" => 0.0, "windgst_max_kmh" => 6.0, "sunset_time" => "18:52", "rain_total_mm" => 1.0, "snow_total_in" => 0.0, "windspd_max_mph" => 2.0, "windspd_max_kts" => 2.0, "sunrise_time" => "06:10", "slp_min_in" => 30.01, "precip_total_mm" => 1.9, "windgst_max_kts" => 3.0, "temp_max_f" => 72.6, "snow_total_mm" => 0.0, "windgst_max_ms" => 1.8, "precip_total_in" => 0.1, "humid_min_pct" => 95.0, "slp_max_in" => 30.05, "date" => "09/06/2024", "windspd_max_kmh" => 4.0, "windspd_max_ms" => 1.1, "Timeframes" => Any[Dict{String, Any}("windspd_kmh" => 4.0, "cloud_high_pct" => 7.0, "windgst_kts" => 3.0, "snow_accum_cm" => 0.0, "cloudtotal_pct" => 43.0, "snow_mm" => 0.0, "precip_mm" => 1.1, "feelslike_c" => 24.2, "winddir_deg" => 215.0, "windspd_mph" => 2.0, "time" => 2000, "temp_c" => 22.6, "slp_mb" => 1013.0, "windgst_ms" => 1.8, "date" => "09/06/2024", "humid_pct" => 95.0, "snow_in" => 0.0, "utcdate" => "10/06/2024", "windspd_ms" => 1.1, "wx_desc" => "Light rain shower", "prob_precip_pct" => "<1", "wx_code" => 80, "precip_in" => 0.0, "windgst_mph" => 4.0, "rain_in" => 0.0, "wx_icon" => "IsoRainSwrsNight.gif", "dewpoint_c" => 21.7, "temp_f" => 72.6, "feelslike_f" => 75.5, "snow_accum_in" => 0.0, "dewpoint_f" => 71.0, "rain_mm" => 1.0, "vis_mi" => 6.2, "cloud_mid_pct" => 24.0, "winddir_compass" => "SW", "cloud_low_pct" => 34.0, "windspd_kts" => 2.0, "utctime" => 0, "windgst_kmh" => 6.0, "slp_in" => 30.01, "vis_km" => 10.0), Dict{String, Any}("windspd_kmh" => 2.0, "cloud_high_pct" => 11.0, "windgst_kts" => 2.0, "snow_accum_cm" => 0.0, "cloudtotal_pct" => 59.0, "snow_mm" => 0.0, "precip_mm" => 0.8, "feelslike_c" => 23.1, "winddir_deg" => 224.0, "windspd_mph" => 1.0, "time" => 2300, "temp_c" => 21.2, "slp_mb" => 1015.0, "windgst_ms" => 1.0, "date" => "09/06/2024", "humid_pct" => 96.0, "snow_in" => 0.0, "utcdate" => "10/06/2024", "windspd_ms" => 0.5, "wx_desc" => "Light rain shower", "prob_precip_pct" => "<1", "wx_code" => 80, "precip_in" => 0.0, "windgst_mph" => 2.0, "rain_in" => 0.0, "wx_icon" => "IsoRainSwrsNight.gif", "dewpoint_c" => 20.6, "temp_f" => 70.2, "feelslike_f" => 73.5, "snow_accum_in" => 0.0, "dewpoint_f" => 69.1, "rain_mm" => 0.0, "vis_mi" => 6.2, "cloud_mid_pct" => 24.0, "winddir_compass" => "SW", "cloud_low_pct" => 49.0, "windspd_kts" => 1.0, "utctime" => 300, "windgst_kmh" => 4.0, "slp_in" => 30.05, "vis_km" => 10.0)], "humid_max_pct" => 96.0, "temp_min_f" => 70.2, "slp_max_mb" => 1014.6, "moonset_time" => "22:02", "temp_max_c" => 22.6, "windgst_max_mph" => 4.0), Dict{String, Any}("rain_total_in" => 5.0, "temp_min_c" => 20.5, "moonrise_time" => "09:52", "slp_min_mb" => 1010.6, "prob_precip_pct" => 94.0, "windgst_max_kmh" => 17.0, "sunset_time" => "18:53", "rain_total_mm" => 10.0, "snow_total_in" => 0.0, "windspd_max_mph" => 6.0, "windspd_max_kts" => 6.0, "sunrise_time" => "06:10", "slp_min_in" => 29.93, "precip_total_mm" => 11.7, "windgst_max_kts" => 9.0, "temp_max_f" => 85.4, "snow_total_mm" => 0.0, "windgst_max_ms" => 4.7, "precip_total_in" => 0.5, "humid_min_pct" => 76.0, "slp_max_in" => 30.03, "date" => "10/06/2024", "windspd_max_kmh" => 10.0, "windspd_max_ms" => 2.9, "Timeframes" => Any[Dict{String, Any}("windspd_kmh" => 2.0, "cloud_high_pct" => 11.0, "windgst_kts" => 2.0, "snow_accum_cm" => 0.0, "cloudtotal_pct" => 69.0, "snow_mm" => 0.0, "precip_mm" => 0.1, "feelslike_c" => 22.2, "winddir_deg" => 201.0, "windspd_mph" => 1.0, "time" => 200, "temp_c" => 20.5, "slp_mb" => 1013.0, "windgst_ms" => 1.2, "date" => "10/06/2024", "humid_pct" => 97.0, "snow_in" => 0.0, "utcdate" => "10/06/2024", "windspd_ms" => 0.6, "wx_desc" => "Mist", "prob_precip_pct" => "<1", "wx_code" => 10, "precip_in" => 0.0, "windgst_mph" => 3.0, "rain_in" => 0.0, "wx_icon" => "Mist.gif", "dewpoint_c" => 20.0, "temp_f" => 69.0, "feelslike_f" => 72.0, "snow_accum_in" => 0.0, "dewpoint_f" => 68.0, "ra ...
